# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('learningSet.csv')

# %%
data.shape
# Out:
# (95412, 368)

# %%
data['TARGET_D'].value_counts()
# Out:
# 0.00     90569
# 10.00      941
# 15.00      591
# 20.00      577
# 5.00       503
#          ...
# 4.50         1
# 55.00        1
# 18.25        1
# 16.87        1
# 48.00        1
# Name: TARGET_D, Length: 71, dtype: int64

# %%
data[data['TARGET_D']!=0]['TARGET_D'].plot( kind = 'hist', bins = 100)

# %%
nulls_percent_df = pd.DataFrame(data.isna().sum()/len(data)).reset_index()

# %%
nulls_percent_df.columns = ['columns_name', 'nulls_percentage']

# %%
## histogram of the null values distribution of your 450 columns

nulls_percent_df.sort_values(by = ['nulls_percentage'], ascending  = False).plot(kind = 'hist', bins = 100)

# %%
columns_above_threshold = nulls_percent_df[nulls_percent_df['nulls_percentage'] > 0.25]['columns_name']

# %%
len(columns_above_threshold)
# Out:
# 72

# %%
drop_columns_list = list(columns_above_threshold)

# %%
drop_columns_list
# Out:
# ['NUMCHLD',
#  'WEALTH1',
#  'MBCRAFT',
#  'MBGARDEN',
#  'MBBOOKS',
#  'MBCOLECT',
#  'MAGFAML',
#  'MAGFEM',
#  'MAGMALE',
#  'PUBGARDN',
#  'PUBCULIN',
#  'PUBHLTH',
#  'PUBDOITY',
#  'PUBNEWFN',
#  'PUBPHOTO',
#  'PUBOPP',
#  'WEALTH2',
#  'ADATE_5',
#  'ADATE_10',
#  'ADATE_13',
#  'ADATE_15',
#  'ADATE_17',
#  'ADATE_19',
#  'ADATE_20',
#  'ADATE_21',
#  'ADATE_22',
#  'ADATE_23',
#  'ADATE_24',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_8',
#  'RDATE_9',
#  'RDATE_10',
#  'RDATE_11',
#  'RDATE_12',
#  'RDATE_13',
#  'RDATE_14',
#  'RDATE_15',
#  'RDATE_16',
#  'RDATE_17',
#  'RDATE_18',
#  'RDATE_19',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_22',
#  'RDATE_23',
#  'RDATE_24',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_8',
#  'RAMNT_9',
#  'RAMNT_10',
#  'RAMNT_11',
#  'RAMNT_12',
#  'RAMNT_13',
#  'RAMNT_14',
#  'RAMNT_15',
#  'RAMNT_16',
#  'RAMNT_17',
#  'RAMNT_18',
#  'RAMNT_19',
#  'RAMNT_20',
# ...

# %%
for i in drop_columns_list:
    data.drop([i], axis = 1)

# %%
data.shape
# Out:
# (95412, 481)

# %%
drop_columns_list.remove('WEALTH1')
drop_columns_list.remove('WEALTH2')


for i in drop_columns_list:
    data.drop([i], axis = 1)

# %%
drop_columns_list.remove('WEALTH2')

# %%
for i in drop_columns_list:
    data = data.drop([i], axis = 1)

# %%
data.shape
# Out:
# (95412, 411)

# %%
data.head()
# Out:
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081                    3712      0
# 1     9401     BOA      1    CA  91326                    5202      0
# 2     9001     AMH      1    NC  27017                       0      0
# 3     8701     BRY      0    CA  95953                    2801      0
# 4     8601              0    FL  33176                    2001      0
#
#   RECINHSE RECP3 RECPGVG RECSWEEP MDMAUD DOMAIN CLUSTER   AGE AGEFLAG  \
# 0                                   XXXX     T2      36  60.0
# 1                                   XXXX     S1      14  46.0       E
# 2                                   XXXX     R2      43   NaN
# 3                                   XXXX     R2      44  70.0       E
# 4        X     X                    XXXX     S2      16  78.0       E
#
#   HOMEOWNR CHILD03 CHILD07 CHILD12 CHILD18  INCOME GENDER  WEALTH1  HIT  \
# ...

# %%
data['RECP3'].value_counts()
# Out:
#      93395
# X     2017
# Name: RECP3, dtype: int64

# %%
data['MAILCODE'] = data['MAILCODE'].apply(lambda x: x.replace(" ", "A"))

# %%
data = data.apply(lambda x: x.replace(" ", np.NaN))

# %%
data.head()
# Out:
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081        A      NaN  3712      0
# 1     9401     BOA      1    CA  91326        A      NaN  5202      0
# 2     9001     AMH      1    NC  27017        A      NaN     0      0
# 3     8701     BRY      0    CA  95953        A      NaN  2801      0
# 4     8601     NaN      0    FL  33176        A      NaN  2001      0
#
#   RECINHSE RECP3 RECPGVG RECSWEEP MDMAUD DOMAIN CLUSTER   AGE AGEFLAG  \
# 0      NaN   NaN     NaN      NaN   XXXX     T2      36  60.0     NaN
# 1      NaN   NaN     NaN      NaN   XXXX     S1      14  46.0       E
# 2      NaN   NaN     NaN      NaN   XXXX     R2      43   NaN     NaN
# 3      NaN   NaN     NaN      NaN   XXXX     R2      44  70.0       E
# 4        X     X     NaN      NaN   XXXX     S2      16  78.0       E
#
#   HOMEOWNR CHILD03 CHILD07 CHILD12 CHILD18  INCOME GENDER  WEALTH1  HIT  \
# ...

# %%
data['MAILCODE'].value_counts()
# Out:
# A    94013
# B     1399
# Name: MAILCODE, dtype: int64

# %%
data.isna().sum()/len(data)
# Out:
# ODATEDW     0.000000
# OSOURCE     0.009726
# TCODE       0.000000
# STATE       0.000000
# ZIP         0.000000
#               ...
# MDMAUD_R    0.000000
# MDMAUD_F    0.000000
# MDMAUD_A    0.000000
# CLUSTER2    0.001383
# GEOCODE2    0.003343
# Length: 411, dtype: float64

# %%
# put the NaN information into a dataframe

NaN_df = pd.DataFrame(data.isna().sum()/len(data)).reset_index()

# %%
NaN_df
# Out:
#         index         0
# 0     ODATEDW  0.000000
# 1     OSOURCE  0.009726
# 2       TCODE  0.000000
# 3       STATE  0.000000
# 4         ZIP  0.000000
# ..        ...       ...
# 406  MDMAUD_R  0.000000
# 407  MDMAUD_F  0.000000
# 408  MDMAUD_A  0.000000
# 409  CLUSTER2  0.001383
# 410  GEOCODE2  0.003343
#
# [411 rows x 2 columns]

# %%
# Assign column names for the variable and the percentage of NaN

NaN_df.columns = ['columns_name', 'NaN_percentage']

# %%
#Using a threshold of 25% for filtering

NaN_columns_above_threshold = NaN_df[NaN_df['NaN_percentage'] > 0.25]['columns_name']

# %%
len(NaN_columns_above_threshold)
# Out:
# 47

# %%
NaN_columns_above_threshold_list = list(NaN_columns_above_threshold)

# %%
NaN_columns_above_threshold_list
# Out:
# ['PVASTATE',
#  'RECINHSE',
#  'RECP3',
#  'RECPGVG',
#  'RECSWEEP',
#  'AGEFLAG',
#  'CHILD03',
#  'CHILD07',
#  'CHILD12',
#  'CHILD18',
#  'WEALTH1',
#  'SOLP3',
#  'SOLIH',
#  'MAJOR',
#  'WEALTH2',
#  'GEOCODE',
#  'COLLECT1',
#  'VETERANS',
#  'BIBLE',
#  'CATLG',
#  'HOMEE',
#  'PETS',
#  'CDPLAY',
#  'STEREO',
#  'PCOWNERS',
#  'PHOTO',
#  'CRAFTS',
#  'FISHER',
#  'GARDENIN',
#  'BOATS',
#  'WALKER',
#  'KIDSTUFF',
#  'CARDS',
#  'PLATES',
#  'LIFESRC',
#  'PEPSTRFL',
#  'RFA_5',
#  'RFA_10',
#  'RFA_13',
#  'RFA_15',
#  'RFA_17',
#  'RFA_19',
#  'RFA_20',
#  'RFA_21',
#  'RFA_22',
#  'RFA_23',
#  'RFA_24']

# %%
NaN_columns_above_threshold_list.remove('WEALTH1')
NaN_columns_above_threshold_list.remove('WEALTH2')
NaN_columns_above_threshold_list.remove('VETERANS')
NaN_columns_above_threshold_list.remove('SOLIH')

# %%
for i in NaN_columns_above_threshold_list:
    data = data.drop([i], axis = 1)

# %%
data.shape
# Out:
# (95412, 368)

# %%
## Separate Data into categorical and numerical features
## Put aside our target variable

# %%
Y =  data[['TARGET_B', 'TARGET_D']]

# %%
numericals = data.select_dtypes(np.number)

# %%
numericals = numericals.drop(['TARGET_B', 'TARGET_D'], axis = 1)

# %%
categoricals = data.select_dtypes(np.object)

# %%
categoricals
# Out:
#       OSOURCE STATE    ZIP MAILCODE NOEXCH MDMAUD DOMAIN CLUSTER HOMEOWNR  \
# 0         GRI    IL  61081        A      0   XXXX     T2      36      NaN
# 1         BOA    CA  91326        A      0   XXXX     S1      14        H
# 2         AMH    NC  27017        A      0   XXXX     R2      43        U
# 3         BRY    CA  95953        A      0   XXXX     R2      44        U
# 4         NaN    FL  33176        A      0   XXXX     S2      16        H
# ...       ...   ...    ...      ...    ...    ...    ...     ...      ...
# 95407     ASE    AK  99504        A      0   XXXX     C2      27      NaN
# 95408     DCD    TX  77379        A      0   XXXX     C1      24        H
# 95409     MBC    MI  48910        A      0   XXXX     C3      30      NaN
# 95410     PRV    CA  91320        A      0   XXXX     C1      24        H
# 95411     MCC    NC  28409        A      0   C1CM     C1      24        U
#
#       GENDER DATASRCE SOLIH VETERANS RFA_2 RFA_3 RFA_4 RFA_6 RFA_7 RFA_8  \
# ...

# %%
categoricals.head(10)
# Out:
#   OSOURCE STATE     ZIP MAILCODE NOEXCH MDMAUD DOMAIN CLUSTER HOMEOWNR GENDER  \
# 0     GRI    IL   61081        A      0   XXXX     T2      36      NaN      F
# 1     BOA    CA   91326        A      0   XXXX     S1      14        H      M
# 2     AMH    NC   27017        A      0   XXXX     R2      43        U      M
# 3     BRY    CA   95953        A      0   XXXX     R2      44        U      F
# 4     NaN    FL   33176        A      0   XXXX     S2      16        H      F
# 5     CWR    AL   35603        A      0   XXXX     T2      40      NaN    NaN
# 6     DRK    IN   46755        A      0   XXXX     T2      40        H      F
# 7     NWN    LA   70611        A      0   XXXX     T2      39        U      F
# 8     LIS    IA   51033        A      0   XXXX     R2      45        U      M
# 9     MSD    TN  37127-        A      0   XXXX     T1      35      NaN      M
#
#   DATASRCE SOLIH VETERANS RFA_2 RFA_3 RFA_4 RFA_6 RFA_7 RFA_8 RFA_9 RFA_11  \
# ...

# %%
** later re-assign wrongly c

# %%
df = pd.DataFrame(categoricals['STATE'].value_counts()).reset_index()
df.columns = ['state', 'count']

# %%
df.head()
# Out:
#   STATE  count
# 0    CA  17343
# 1    FL   8376
# 2    TX   7535
# 3    IL   6420
# 4    MI   5654

# %%
other = list(df[df])

# %%
## Create a new empty list called drop_list

drop_list = []
other = list(df[df['count']<2500]['state'])

# %%
other
# Out:
# ['TN',
#  'AZ',
#  'OR',
#  'MN',
#  'CO',
#  'SC',
#  'AL',
#  'KY',
#  'OK',
#  'LA',
#  'KS',
#  'IA',
#  'AR',
#  'MS',
#  'NV',
#  'NM',
#  'NE',
#  'UT',
#  'ID',
#  'MT',
#  'HI',
#  'SD',
#  'WY',
#  'AK',
#  'ND',
#  'AP',
#  'NY',
#  'VA',
#  'OH',
#  'PA',
#  'MD',
#  'NJ',
#  'MA',
#  'CT',
#  'AA',
#  'AE',
#  'ME',
#  'NH',
#  'VT',
#  'RI',
#  'VI',
#  'GU',
#  'WV',
#  'DE',
#  'AS',
#  'DC']

# %%
def clean_state(x):
    if x in other:
        return 'other'
    else:
        return x
    
categoricals['STATE'] = categoricals['STATE'].apply(clean_state)

# %%
categoricals
# Out:
#       OSOURCE STATE    ZIP MAILCODE NOEXCH MDMAUD DOMAIN CLUSTER HOMEOWNR  \
# 0         GRI    IL  61081        A      0   XXXX     T2      36      NaN
# 1         BOA    CA  91326        A      0   XXXX     S1      14        H
# 2         AMH    NC  27017        A      0   XXXX     R2      43        U
# 3         BRY    CA  95953        A      0   XXXX     R2      44        U
# 4         NaN    FL  33176        A      0   XXXX     S2      16        H
# ...       ...   ...    ...      ...    ...    ...    ...     ...      ...
# 95407     ASE    AK  99504        A      0   XXXX     C2      27      NaN
# 95408     DCD    TX  77379        A      0   XXXX     C1      24        H
# 95409     MBC    MI  48910        A      0   XXXX     C3      30      NaN
# 95410     PRV    CA  91320        A      0   XXXX     C1      24        H
# 95411     MCC    NC  28409        A      0   C1CM     C1      24        U
#
#       GENDER DATASRCE SOLIH VETERANS RFA_2 RFA_3 RFA_4 RFA_6 RFA_7 RFA_8  \
# ...

# %%
## dentify columns that over 85% missing values

cat_85 = pd.DataFrame(categoricals.isna().sum()/len(categoricals)).reset_index()

# %%
cat_85.columns = ['columns_name', '85_percentage']

# %%
cat_85
# Out:
#    columns_name  85_percentage
# 0       OSOURCE       0.009726
# 1         STATE       0.000000
# 2           ZIP       0.000000
# 3      MAILCODE       0.000000
# 4        NOEXCH       0.000073
# 5        MDMAUD       0.000000
# 6        DOMAIN       0.024274
# 7       CLUSTER       0.024274
# 8      HOMEOWNR       0.232969
# 9        GENDER       0.030992
# 10     DATASRCE       0.223033
# 11        SOLIH       0.935019
# 12     VETERANS       0.890727
# 13        RFA_2       0.000000
# 14        RFA_3       0.020438
# 15        RFA_4       0.024232
# 16        RFA_6       0.037280
# 17        RFA_7       0.093007
# 18        RFA_8       0.036798
# 19        RFA_9       0.117857
# 20       RFA_11       0.109232
# 21       RFA_12       0.093521
# 22       RFA_14       0.197742
# 23       RFA_16       0.213988
# 24       RFA_18       0.222855
# 25       RFA_2R       0.000000
# 26       RFA_2A       0.000000
# 27     MDMAUD_R       0.000000
# 28     MDMAUD_F       0.000000
# ...

# %%
cat_85_above = cat_85[cat_85['85_percentage'] > 0.85]['columns_name']

# %%
cat_85_above
# Out:
# 11       SOLIH
# 12    VETERANS
# Name: columns_name, dtype: object

# %%
cat_85_above_list = list(cat_85_above)

# %%
cat_85_above_list
# Out:
# ['SOLIH', 'VETERANS']

# %%
for item in cat_85_above_list:
    categoricals = categoricals.drop([item], axis = 1)

# %% [markdown]
# ### Reduce the number of categories in the column GENDER. The column should only have either "M" for males, "F" for females, and "other" for all the rest

# %%
categoricals['GENDER'].value_counts()
# Out:
# F    51277
# M    39094
# U     1715
# J      365
# A        2
# C        2
# Name: GENDER, dtype: int64

# %%
def clean_gender(x):
    if x == 'F':
        return 'F'
    elif x == 'M':
        return 'M'
    else:
        return 'other'
categoricals['GENDER'] = list(map(clean_gender, categoricals['GENDER']))
categoricals['GENDER'].value_counts()
# Out:
# F        51277
# M        39094
# other     5041
# Name: GENDER, dtype: int64
